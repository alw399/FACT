# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import os 
import sys 
import json

# %%
import pyBigWig

bw_path = '../data/bws_for_predictor/SPT16_4D_2HdTAG_SOX2_S46_1_120_sorted.bw'
bw = pyBigWig.open(bw_path)

# %%
bw.header()
# Out:
# {'version': 4,
#  'nLevels': 6,
#  'nBasesCovered': 2730871774,
#  'minVal': 0,
#  'maxVal': 9269,
#  'sumData': 2190116940,
#  'sumSquared': 386826870463}

# %%
bw.chroms()
# Out:
# {'chr10': 130694993,
#  'chr11': 122082543,
#  'chr12': 120129022,
#  'chr13': 120421639,
#  'chr14': 124902244,
#  'chr15': 104043685,
#  'chr16': 98207768,
#  'chr17': 94987271,
#  'chr18': 90702639,
#  'chr19': 61431566,
#  'chr1': 195471971,
#  'chr1_GL456210_random': 169725,
#  'chr1_GL456211_random': 241735,
#  'chr1_GL456212_random': 153618,
#  'chr1_GL456213_random': 39340,
#  'chr1_GL456221_random': 206961,
#  'chr2': 182113224,
#  'chr3': 160039680,
#  'chr4': 156508116,
#  'chr4_GL456216_random': 66673,
#  'chr4_GL456350_random': 227966,
#  'chr4_JH584292_random': 14945,
#  'chr4_JH584293_random': 207968,
#  'chr4_JH584294_random': 191905,
#  'chr4_JH584295_random': 1976,
#  'chr5': 151834684,
#  'chr5_GL456354_random': 195993,
#  'chr5_JH584296_random': 199368,
#  'chr5_JH584297_random': 205776,
#  'chr5_JH584298_random': 184189,
#  'chr5_JH584299_random': 953012,
#  'chr6': 149736546,
#  'chr7': 145441459,
#  'chr7_GL456219_random': 175968,
#  'chr8': 129401213,
# ...

# %%
bw.stats("chr10",type="mean", nBins=2)
# Out:
# [0.7631150892974367, 0.8823992180541531]

# %%
import pyfaidx
import pyBigWig

fasta_path = '../data/GRCm38.primary_assembly.genome.fa'
fasta = pyfaidx.Fasta(fasta_path, as_raw=True, sequence_always_upper=True)
fasta_chroms = set(fasta.keys())
bw_chroms = set(bw.chroms().keys())

# %%
common = fasta_chroms & bw_chroms
common
# Out:
# {'chr1',
#  'chr10',
#  'chr11',
#  'chr12',
#  'chr13',
#  'chr14',
#  'chr15',
#  'chr16',
#  'chr17',
#  'chr18',
#  'chr19',
#  'chr2',
#  'chr3',
#  'chr4',
#  'chr5',
#  'chr6',
#  'chr7',
#  'chr8',
#  'chr9',
#  'chrM',
#  'chrX',
#  'chrY'}

# %%
peaks = bw.stats("chr3", type="mean", nBins=1000)
plt.plot(peaks)
